# %%
import pandas as pd

# %%
s=pd.series([3,5,67,2,4])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-7683d5f2cf7c> in <module>()
# ----> 1 s=pd.series([3,5,67,2,4])
#
# AttributeError: 'module' object has no attribute 'series'

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f4d5d0c0671b> in <module>()
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
s=pd.Series([3,5,67,2,4])

# %%
s
# Out:
# 0     3
# 1     5
# 2    67
# 3     2
# 4     4
# dtype: int64

# %%
s.name="OneDArray"

# %%
s
# Out:
# 0     3
# 1     5
# 2    67
# 3     2
# 4     4
# Name: OneDArray, dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.plot

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.values
# Out:
# array([ 3,  5, 67,  2,  4], dtype=int64)

# %%
s.plot(title="Hi",legent=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-ed29d94c8053> in <module>()
# ----> 1 s.plot(title="Hi",legent=True)
#
# c:\users\mhoucheime\documents\datascience2016fall-master\dsenv\lib\site-packages\pandas\tools\plotting.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3561                            colormap=colormap, table=table, yerr=yerr,
#    3562                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3563                            **kwds)
#    3564     __call__.__doc__ = plot_series.__doc__
#    3565
#
# ...

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s.plot(title="Hi",legend=True)

# %%
s.count()
# Out:
# 5

# %%
s*3
# Out:
# 0      9
# 1     15
# 2    201
# 3      6
# 4     12
# Name: OneDArray, dtype: int64

# %%
s.value_counts()
# Out:
# 4     1
# 5     1
# 67    1
# 3     1
# 2     1
# Name: OneDArray, dtype: int64

# %%
s.sort_values()
# Out:
# 3     2
# 0     3
# 4     4
# 1     5
# 2    67
# Name: OneDArray, dtype: int64

# %%
s.abs?

# %%
obj2['a']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-768f38482c06> in <module>()
# ----> 1 obj2['a']
#
# NameError: name 'obj2' is not defined

# %%
b=pd.Series(['a','b','c'])

# %%
'a'in b
# Out:
# False

# %%
1 in b
# Out:
# True

# %%
b
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
'b' in b
# Out:
# False

# %%
'b' in b.values
# Out:
# True

# %%
obj2=Series([4,7,-5,3]),index=['d','b','a','c']
obj2
# Out:
#   File "<ipython-input-28-20c36c3cda70>", line 1
#     obj2=Series([4,7,-5,3]),index=['d','b','a','c']
# SyntaxError: can't assign to function call

# %%
data{'state':['Ohio','Ohio','Ohio','Nevada','Nevada'],
     'year':[2000,2001,2002,2001,2002],
     'pop':[1.5,1.7,3.6,2.4,2.9]}
# Out:
#   File "<ipython-input-29-55192f636744>", line 1
#     data{'state':['Ohio','Ohio','Ohio','Nevada','Nevada'],
#         ^
# SyntaxError: invalid syntax

# %%
data={'state':['Ohio','Ohio','Ohio','Nevada','Nevada'],
     'year':[2000,2001,2002,2001,2002],
     'pop':[1.5,1.7,3.6,2.4,2.9]}

# %%
data
# Out:
# {'pop': [1.5, 1.7, 3.6, 2.4, 2.9],
#  'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
#  'year': [2000, 2001, 2002, 2001, 2002]}

# %%
frame2=DataFrame(data,columns='year','state','pop','debt'],
                index=['one','two','three','four','five'])
# Out:
#   File "<ipython-input-32-5420802b68b1>", line 1
#     frame2=DataFrame(data,columns='year','state','pop','debt'],
#                                                              ^
# SyntaxError: invalid syntax

# %%
frame2=DataFrame(data,columns=['year','state','pop','debt'],
                index=['one','two','three','four','five'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-7f34db67e6cf> in <module>()
# ----> 1 frame2=DataFrame(data,columns=['year','state','pop','debt'],
#       2                 index=['one','two','three','four','five'])
#
# NameError: name 'DataFrame' is not defined

# %%
from pandas import DataFrame

# %%
frame2=DataFrame(data,columns=['year','state','pop','debt'],
                index=['one','two','three','four','five'])

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN

# %%
frame2.columns
# Out:
# Index([u'year', u'state', u'pop', u'debt'], dtype='object')

# %%
frame2.index
# Out:
# Index([u'one', u'two', u'three', u'four', u'five'], dtype='object')

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# Name: year, dtype: int64

# %%
frame2.['year']
# Out:
#   File "<ipython-input-43-02dd652c0579>", line 1
#     frame2.['year']
#            ^
# SyntaxError: invalid syntax

# %%
frame2[year]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-e200971d211b> in <module>()
# ----> 1 frame2[year]
#
# NameError: name 'year' is not defined

# %%
frame2['year']
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# Name: year, dtype: int64

# %%
frame2.debt=1.0

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   1.0
# two    2001    Ohio  1.7   1.0
# three  2002    Ohio  3.6   1.0
# four   2001  Nevada  2.4   1.0
# five   2002  Nevada  2.9   1.0

# %%
frame2.debt=np.arange(5)

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5     0
# two    2001    Ohio  1.7     1
# three  2002    Ohio  3.6     2
# four   2001  Nevada  2.4     3
# five   2002  Nevada  2.9     4

# %%
import pandas.io.data as web

# %%
import pandas.io.data as web

# %%
all_data={}

# %%
for ticket in ['AAPL','IBM','MSFT','GOOGL']:
    all_data[ticket]=web.get_data_yahoo(ticket)

# %%
price=DataFrame({tic:data['Adj Close']
                for tic, data in all_data.iteritems()})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37a5c70931ed> in <module>()
# ----> 1 price=DataFrame({tic:data['Adj Close']
#       2                 for tic, data in all_data.iteritems()})
#
# NameError: name 'DataFrame' is not defined

# %%
price
# Out:
#                   AAPL        GOOG         IBM       MSFT
# Date
# 2010-01-04   27.990226  313.062468  113.304536  25.884104
# 2010-01-05   28.038618  311.683844  111.935822  25.892466
# 2010-01-06   27.592626  303.826685  111.208683  25.733566
# 2010-01-07   27.541619  296.753749  110.823732  25.465944
# 2010-01-08   27.724725  300.709808  111.935822  25.641571
# 2010-01-11   27.480148  300.255255  110.763844  25.315406
# 2010-01-12   27.167562  294.945572  111.644958  25.148142
# 2010-01-13   27.550775  293.252243  111.405433  25.382312
# 2010-01-14   27.391211  294.630868  113.184773  25.892466
# 2010-01-15   26.933449  289.710772  112.731385  25.808835
# 2010-01-19   28.124939  293.516976  114.750251  26.009552
# 2010-01-20   27.692027  289.915587  111.422546  25.583028
# 2010-01-21   27.213337  291.199286  110.353231  25.097963
# 2010-01-22   25.863592  274.730736  107.359151  24.219826
# 2010-01-25   26.559391  269.730740  107.889534  24.520902
# ...

# %%
volume=DataFrame({tic:data['Volume']
                 for tic, data in all_data.iteritems()})

# %%
volume
# Out:
#                  AAPL      GOOG       IBM       MSFT
# Date
# 2010-01-04  123432400   3927000   6155300   38409100
# 2010-01-05  150476200   6031900   6841400   49749600
# 2010-01-06  138040000   7987100   5605300   58182400
# 2010-01-07  119282800  12876600   5840600   50559700
# 2010-01-08  111902700   9483900   4197200   51197400
# 2010-01-11  115557400  14479800   5730400   68754700
# 2010-01-12  148614900   9742900   8081500   65912100
# 2010-01-13  151473000  13041800   6455400   51863500
# 2010-01-14  108223500   8511900   7111800   63228100
# 2010-01-15  148516900  10909600   8494400   79913200
# 2010-01-19  182501900   8665700  13916200   46575700
# 2010-01-20  153038200   6525700  15197500   54849500
# 2010-01-21  152038600  12662600   9608600   73086700
# 2010-01-22  220441900  13651700  10088600  102004600
# 2010-01-25  266424900   8872800   5738500   63373000
# 2010-01-26  466777500   8743600   7135300   66639900
# 2010-01-27  430642100   7958400   8719200   63949500
# ...

# %%
for ticket in ['DOW']:
    all_data[ticket]=web.get_data_yahoo(ticket)

# %%
price=DataFrame({tic:data['Adj Close']
                for tic, data in all_data.iteritems()})

# %%
# Out:
#                   AAPL        DOW        GOOG         IBM       MSFT
# Date
# 2010-01-04   27.990226  23.487697  313.062468  113.304536  25.884104
# 2010-01-05   28.038618  24.534098  311.683844  111.935822  25.892466
# 2010-01-06   27.592626  24.968758  303.826685  111.208683  25.733566
# 2010-01-07   27.541619  24.984857  296.753749  110.823732  25.465944
# 2010-01-08   27.724725  25.073397  300.709808  111.935822  25.641571
# 2010-01-11   27.480148  24.759477  300.255255  110.763844  25.315406
# 2010-01-12   27.167562  24.839970  294.945572  111.644958  25.148142
# 2010-01-13   27.550775  24.751428  293.252243  111.405433  25.382312
# 2010-01-14   27.391211  24.574345  294.630868  113.184773  25.892466
# 2010-01-15   26.933449  24.139685  289.710772  112.731385  25.808835
# 2010-01-19   28.124939  24.695084  293.516976  114.750251  26.009552
# 2010-01-20   27.692027  24.437508  289.915587  111.422546  25.583028
# ...

# %%
pip install yahoo-finance
# Out:
#   File "<ipython-input-70-7941ca40ebaf>", line 1
#     pip install yahoo-finance
#               ^
# SyntaxError: invalid syntax

# %%
import yahoo-finance
# Out:
#   File "<ipython-input-77-b8bb20759441>", line 1
#     import yahoo-finance
#                 ^
# SyntaxError: invalid syntax

# %%
from yahoo_finance import Share
import time
import serial
StockShares = ['DOW','YHOO','BAC','F','JPM','TWTR','CHK','PBR','FIT','COG','ABX','FCX','GE','TRGP','CNX','BSX','MRC','NKE','NEM','PBRA','HST','BP','MRK','HON','MET','CLR','WPX' \
,'EXC','JCP','YELP','GNC','TSLA','VRX','P','NFLX','CMG','SM','WYNN','SHAK','ICON']

ser = serial.Serial('COM1',9600)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-78-4341bfc50998> in <module>()
# ----> 1 from yahoo_finance import Share
#       2 import time
#       3 import serial
#       4 StockShares = ['DOW','YHOO','BAC','F','JPM','TWTR','CHK','PBR','FIT','COG','ABX','FCX','GE','TRGP','CNX','BSX','MRC','NKE','NEM','PBRA','HST','BP','MRK','HON','MET','CLR','WPX' ,'EXC','JCP','YELP','GNC','TSLA','VRX','P','NFLX','CMG','SM','WYNN','SHAK','ICON']
#       5
#
# ImportError: No module named yahoo_finance

# %%
for ticket in ['MMM','AXP','AAPL','BA','CAT','CVX','CSCO','KO','DIS','DD','XOM','GE','GS','HD','IBM','INTC','JNJ','JPM','MCD','MRK','MSFT','NKE','PFE','PG','TRV','UTX','UNH','VZ','V','WMT']:
    all_data[ticket]=web.get_data_yahoo(ticket)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d9c0f66dc8d7> in <module>()
#       1 for ticket in ['MMM','AXP','AAPL','BA','CAT','CVX','CSCO','KO','DIS','DD','XOM','GE','GS','HD','IBM','INTC','JNJ','JPM','MCD','MRK','MSFT','NKE','PFE','PG','TRV','UTX','UNH','VZ','V','WMT']:
# ----> 2     all_data[ticket]=web.get_data_yahoo(ticket)
#
# NameError: name 'web' is not defined

# %%
price=DataFrame({tic:data['Adj Close']
                for tic, data in all_data.iteritems()})

# %%
price
# Out:
#                   AAPL        AXP          BA        BIS        CAT  \
# Date
# 2010-01-04   27.990226  36.870188   47.580271        NaN  48.631484
# 2010-01-05   28.038618  36.789098   49.138614        NaN  49.212903
# 2010-01-06   27.592626  37.383778   50.629202        NaN  49.362411
# 2010-01-07   27.541619  37.990097   52.678763        NaN  49.561752
# 2010-01-08   27.724725  37.962949   52.170606        NaN  50.118254
# 2010-01-11   27.480148  37.528570   51.552350        NaN  53.266217
# 2010-01-12   27.167562  38.026296   51.179704        NaN  51.696391
# 2010-01-13   27.550775  38.143941   51.797960        NaN  51.771145
# 2010-01-14   27.391211  38.623567   52.136731        NaN  51.480434
# 2010-01-15   26.933449  38.361129   51.510005        NaN  50.276213
# 2010-01-19   28.124939  38.876954   51.366029        NaN  50.953588
# 2010-01-20   27.692027  38.895054   50.984912        NaN  49.975157
# 2010-01-21   27.213337  38.152989   50.137987        NaN  47.541628
# ...

# %%
price["Sum"] =0

# %%
price=DataFrame({tic:data['Adj Close']
                for tic, data in all_data.iteritems()})

# %%
price.shape
# Out:
# (1704, 34)

# %%
price.columns[0]
# Out:
# 'AAPL'

# %%
price.columns[0:]
# Out:
# Index([u'AAPL', u'AXP', u'BA', u'BIS', u'CAT', u'CSCO', u'CVX', u'DD', u'DIS',
#        u'DJIA', u'DOW', u'GE', u'GOOG', u'GS', u'HD', u'IBM', u'INTC', u'JNJ',
#        u'JPM', u'KO', u'MCD', u'MMM', u'MRK', u'MSFT', u'NKE', u'PFE', u'PG',
#        u'TRV', u'UNH', u'UTX', u'V', u'VZ', u'WMT', u'XOM'],
#       dtype='object')

# %%
Aggregate = pd.Series(price.sum(axis=1))

# %%
Aggregate
# Out:
# Date
# 2010-01-04    1605.064463
# 2010-01-05    1605.120113
# 2010-01-06    1596.269782
# 2010-01-07    1597.831373
# 2010-01-08    1600.067167
# 2010-01-11    1600.664380
# 2010-01-12    1588.577221
# 2010-01-13    1594.403969
# 2010-01-14    1599.231381
# 2010-01-15    1580.568013
# 2010-01-19    1601.393789
# 2010-01-20    1586.030626
# 2010-01-21    1557.045962
# 2010-01-22    1511.169735
# 2010-01-25    1509.799804
# 2010-01-26    1507.038876
# 2010-01-27    1513.200189
# 2010-01-28    1498.154955
# 2010-01-29    1485.703798
# 2010-02-01    1504.583936
# 2010-02-02    1517.526413
# 2010-02-03    1520.586852
# 2010-02-04    1478.835136
# 2010-02-05    1484.849674
# 2010-02-08    1472.767529
# 2010-02-09    1492.647863
# 2010-02-10    1490.572514
# 2010-02-11    1504.018474
# 2010-02-12    1497.660434
# 2010-02-16    1522.442098
#                  ...
# 2016-08-26    3535.379664
# 2016-08-29    3554.450761
# 2016-08-30    3546.539444
# 2016-08-31    3536.904293
# ...

# %%
for ticket in ['DJIA']:
    all_data[ticket]=web.get_data_yahoo(ticket)

# %%
DJIA=DataFrame({tic:data['Adj Close']
                for tic, data in all_data.iteritems()})

# %%
DJIA
# Out:
#                   AAPL        AXP          BA        BIS        CAT  \
# Date
# 2010-01-04   27.990226  36.870188   47.580271        NaN  48.631484
# 2010-01-05   28.038618  36.789098   49.138614        NaN  49.212903
# 2010-01-06   27.592626  37.383778   50.629202        NaN  49.362411
# 2010-01-07   27.541619  37.990097   52.678763        NaN  49.561752
# 2010-01-08   27.724725  37.962949   52.170606        NaN  50.118254
# 2010-01-11   27.480148  37.528570   51.552350        NaN  53.266217
# 2010-01-12   27.167562  38.026296   51.179704        NaN  51.696391
# 2010-01-13   27.550775  38.143941   51.797960        NaN  51.771145
# 2010-01-14   27.391211  38.623567   52.136731        NaN  51.480434
# 2010-01-15   26.933449  38.361129   51.510005        NaN  50.276213
# 2010-01-19   28.124939  38.876954   51.366029        NaN  50.953588
# 2010-01-20   27.692027  38.895054   50.984912        NaN  49.975157
# 2010-01-21   27.213337  38.152989   50.137987        NaN  47.541628
# ...

# %%
for ticket in ['DJIA']:
    all_data[ticket]=web.get_data_yahoo(ticket)

# %%
DJIA=DataFrame({tic:data['Adj Close']
                for tic, data in all_data.iteritems()})

# %%
DJIA
# Out:
#                   AAPL        AXP          BA        BIS        CAT  \
